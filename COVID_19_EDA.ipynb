# %% [markdown]
# # 🦠 COVID-19 Global Data Analysis (EDA Project)
#
# **Author:** Sai Patil
# **Objective:** Perform Exploratory Data Analysis (EDA) and visualize global COVID-19 trends using Matplotlib.
# **Dataset:** `worldometer_coronavirus_daily_data.csv`
#
# This project aims to explore the COVID-19 dataset to understand global trends, country-wise distributions, and time-based patterns of cases and deaths.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('worldometer_coronavirus_daily_data.csv')

# %%
df.columns
# Out:
# Index(['date', 'country', 'cumulative_total_cases', 'daily_new_cases',
#        'active_cases', 'cumulative_total_deaths', 'daily_new_deaths'],
#       dtype='object')

# %%
df.head()
# Out:
#         date      country  cumulative_total_cases  daily_new_cases  \
# 0  2020-2-15  Afghanistan                     0.0              NaN
# 1  2020-2-16  Afghanistan                     0.0              NaN
# 2  2020-2-17  Afghanistan                     0.0              NaN
# 3  2020-2-18  Afghanistan                     0.0              NaN
# 4  2020-2-19  Afghanistan                     0.0              NaN
#
#    active_cases  cumulative_total_deaths  daily_new_deaths
# 0           0.0                      0.0               NaN
# 1           0.0                      0.0               NaN
# 2           0.0                      0.0               NaN
# 3           0.0                      0.0               NaN
# 4           0.0                      0.0               NaN

# %%
df.tail()
# Out:
#              date   country  cumulative_total_cases  daily_new_cases  \
# 184782  2022-5-10  Zimbabwe                248642.0            106.0
# 184783  2022-5-11  Zimbabwe                248778.0            136.0
# 184784  2022-5-12  Zimbabwe                248943.0            165.0
# 184785  2022-5-13  Zimbabwe                249131.0            188.0
# 184786  2022-5-14  Zimbabwe                249206.0             75.0
#
#         active_cases  cumulative_total_deaths  daily_new_deaths
# 184782         963.0                   5481.0               2.0
# 184783        1039.0                   5481.0               0.0
# 184784        1158.0                   5481.0               0.0
# 184785        1283.0                   5482.0               1.0
# 184786        1307.0                   5482.0               0.0

# %%
df.describe()
# Out:
#        cumulative_total_cases  daily_new_cases  active_cases  \
# count            1.847870e+05    174329.000000  1.667470e+05
# mean             7.251089e+05      2987.633285  6.239283e+04
# std              3.681471e+06     17803.232663  3.955641e+05
# min              0.000000e+00      -322.000000 -1.432100e+04
# 25%              1.099000e+03         0.000000  6.000000e+01
# 50%              1.775600e+04        58.000000  1.386000e+03
# 75%              2.238085e+05       728.000000  1.462050e+04
# max              8.420947e+07    909610.000000  1.793543e+07
#
#        cumulative_total_deaths  daily_new_deaths
# count             1.782270e+05     157850.000000
# mean              1.388600e+04         39.831834
# std               6.049521e+04        181.102770
# min               0.000000e+00        -39.000000
# 25%               2.400000e+01          0.000000
# 50%               3.040000e+02          1.000000
# 75%               4.111000e+03         12.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184787 entries, 0 to 184786
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   date                     184787 non-null  object
#  1   country                  184787 non-null  object
#  2   cumulative_total_cases   184787 non-null  float64
#  3   daily_new_cases          174329 non-null  float64
#  4   active_cases             166747 non-null  float64
#  5   cumulative_total_deaths  178227 non-null  float64
#  6   daily_new_deaths         157850 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 9.9+ MB

# %%
df.isnull()
# Out:
#          date  country  cumulative_total_cases  daily_new_cases  active_cases  \
# 0       False    False                   False             True         False
# 1       False    False                   False             True         False
# 2       False    False                   False             True         False
# 3       False    False                   False             True         False
# 4       False    False                   False             True         False
# ...       ...      ...                     ...              ...           ...
# 184782  False    False                   False            False         False
# 184783  False    False                   False            False         False
# 184784  False    False                   False            False         False
# 184785  False    False                   False            False         False
# 184786  False    False                   False            False         False
#
# ...

# %%
df.isnull().sum()
# Out:
# date                           0
# country                        0
# cumulative_total_cases         0
# daily_new_cases            10458
# active_cases               18040
# cumulative_total_deaths     6560
# daily_new_deaths           26937
# dtype: int64

# %%
# Check for duplicates
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %% [markdown]
# ### Dropping all null values

# %%
df.dropna()
# Out:
#              date      country  cumulative_total_cases  daily_new_cases  \
# 10      2020-2-25  Afghanistan                     1.0              0.0
# 11      2020-2-26  Afghanistan                     1.0              0.0
# 12      2020-2-27  Afghanistan                     1.0              0.0
# 13      2020-2-28  Afghanistan                     1.0              0.0
# 14      2020-2-29  Afghanistan                     1.0              0.0
# ...           ...          ...                     ...              ...
# 184782  2022-5-10     Zimbabwe                248642.0            106.0
# 184783  2022-5-11     Zimbabwe                248778.0            136.0
# 184784  2022-5-12     Zimbabwe                248943.0            165.0
# 184785  2022-5-13     Zimbabwe                249131.0            188.0
# 184786  2022-5-14     Zimbabwe                249206.0             75.0
#
#         active_cases  cumulative_total_deaths  daily_new_deaths
# ...

# %%
df[10:20]
# Out:
#          date      country  cumulative_total_cases  daily_new_cases  \
# 10  2020-2-25  Afghanistan                     1.0              0.0
# 11  2020-2-26  Afghanistan                     1.0              0.0
# 12  2020-2-27  Afghanistan                     1.0              0.0
# 13  2020-2-28  Afghanistan                     1.0              0.0
# 14  2020-2-29  Afghanistan                     1.0              0.0
# 15  2020-3-01  Afghanistan                     1.0              0.0
# 16  2020-3-02  Afghanistan                     1.0              0.0
# 17  2020-3-03  Afghanistan                     1.0              0.0
# 18  2020-3-04  Afghanistan                     1.0              0.0
# 19  2020-3-05  Afghanistan                     1.0              0.0
#
#     active_cases  cumulative_total_deaths  daily_new_deaths
# 10           1.0                      0.0               0.0
# 11           1.0                      0.0               0.0
# ...

# %%
df.loc[100:115,['country','active_cases']]
# Out:
#          country  active_cases
# 100  Afghanistan        9857.0
# 101  Afghanistan       10483.0
# 102  Afghanistan       11091.0
# 103  Afghanistan       11592.0
# 104  Afghanistan       12154.0
# 105  Afghanistan       12973.0
# 106  Afghanistan       13620.0
# 107  Afghanistan       14057.0
# 108  Afghanistan       14789.0
# 109  Afghanistan       15451.0
# 110  Afghanistan       16169.0
# 111  Afghanistan       16898.0
# 112  Afghanistan       17394.0
# 113  Afghanistan       18110.0
# 114  Afghanistan       18377.0
# 115  Afghanistan       18424.0

# %% [markdown]
# ### Displaying columns wtih active cases more than 10500

# %%
df[df['active_cases']>10500]
# Out:
#              date      country  cumulative_total_cases  daily_new_cases  \
# 102     2020-5-27  Afghanistan                 12456.0            625.0
# 103     2020-5-28  Afghanistan                 13036.0            580.0
# 104     2020-5-29  Afghanistan                 13659.0            623.0
# 105     2020-5-30  Afghanistan                 14525.0            866.0
# 106     2020-5-31  Afghanistan                 15205.0            680.0
# ...           ...          ...                     ...              ...
# 184668  2022-1-16     Zimbabwe                226078.0            144.0
# 184669  2022-1-17     Zimbabwe                226460.0            382.0
# 184670  2022-1-18     Zimbabwe                226887.0            427.0
# 184671  2022-1-19     Zimbabwe                227552.0            665.0
# 184672  2022-1-20     Zimbabwe                227695.0            143.0
#
#         active_cases  cumulative_total_deaths  daily_new_deaths
# ...

# %% [markdown]
# ### Displaying columns with country India and active cases above 220000

# %%
India=df[df['country']=='India']

# %%
India[India['active_cases']>220000]
# Out:
#             date country  cumulative_total_cases  daily_new_cases  \
# 77240  2020-6-30   India                585792.0          18256.0
# 77241  2020-7-01   India                605220.0          19428.0
# 77242  2020-7-02   India                627168.0          21948.0
# 77243  2020-7-03   India                649889.0          22721.0
# 77244  2020-7-04   India                673904.0          24015.0
# ...          ...     ...                     ...              ...
# 77834  2022-2-14   India              42692943.0          27409.0
# 77835  2022-2-15   India              42723558.0          30615.0
# 77836  2022-2-16   India              42754315.0          30757.0
# 77837  2022-2-17   India              42780235.0          25920.0
# 77838  2022-2-18   India              42802505.0          22270.0
#
#        active_cases  cumulative_total_deaths  daily_new_deaths
# 77240      220239.0                  17717.0             518.0
# ...

# %% [markdown]
# ### Maximum deaths on any day in India

# %%
India['daily_new_deaths'].max()
# Out:
# 5093.0

# %% [markdown]
# ### Total Deaths in India

# %%
India['daily_new_deaths'].sum()
# Out:
# 524214.0

# %% [markdown]
# ### Total Cases In India

# %%
India['daily_new_cases'].sum()
# Out:
# 43121596.0

# %% [markdown]
# ### Dates on which daily cases were 0 in India

# %%
India[India['daily_new_cases']==0]
# Out:
#             date country  cumulative_total_cases  daily_new_cases  \
# 77105  2020-2-16   India                     3.0              0.0
# 77106  2020-2-17   India                     3.0              0.0
# 77107  2020-2-18   India                     3.0              0.0
# 77108  2020-2-19   India                     3.0              0.0
# 77109  2020-2-20   India                     3.0              0.0
# 77110  2020-2-21   India                     3.0              0.0
# 77111  2020-2-22   India                     3.0              0.0
# 77112  2020-2-23   India                     3.0              0.0
# 77113  2020-2-24   India                     3.0              0.0
# 77114  2020-2-25   India                     3.0              0.0
# 77115  2020-2-26   India                     3.0              0.0
# 77116  2020-2-27   India                     3.0              0.0
# 77117  2020-2-28   India                     3.0              0.0
# ...

# %% [markdown]
# ### Data of World corona cases on the date 2020-6-30

# %%
World=df[df['date']=='2020-6-30']
World
# Out:
#              date                    country  cumulative_total_cases  \
# 136     2020-6-30                Afghanistan                 31517.0
# 956     2020-6-30                    Albania                  2535.0
# 1776    2020-6-30                    Algeria                 13907.0
# 2596    2020-6-30                    Andorra                   855.0
# 3416    2020-6-30                     Angola                   284.0
# ...           ...                        ...                     ...
# 180823  2020-6-30  Wallis And Futuna Islands                     0.0
# 181643  2020-6-30             Western Sahara                    10.0
# 182463  2020-6-30                      Yemen                  1190.0
# 183283  2020-6-30                     Zambia                  1594.0
# 184103  2020-6-30                   Zimbabwe                   591.0
#
#         daily_new_cases  active_cases  cumulative_total_deaths  \
# 136               279.0       16640.0                    746.0
# ...

# %% [markdown]
# ### Total number of cases on the date 2020-6-30 worldwide

# %%
World['daily_new_cases'].sum()
# Out:
# 183778.0

# %% [markdown]
# ### Total number of deaths on the date 2020-6-30 worldwide

# %%
World['daily_new_deaths'].sum()
# Out:
# 5769.0

# %%
# Total cumulative cases by country
country_cases = df.groupby('country')['cumulative_total_cases'].max().sort_values(ascending=False)
country_cases.head(10)
# Out:
# country
# USA            84209473.0
# India          43121599.0
# Brazil         30682094.0
# France         29160802.0
# Germany        25774509.0
# UK             22159805.0
# Russia         18255337.0
# South Korea    17756627.0
# Italy          17030711.0
# Turkey         15053168.0
# Name: cumulative_total_cases, dtype: float64

# %% [markdown]
# ## Plots & Charts

# %% [markdown]
# ### Active cases according to date in India

# %%
x=India['date']
y=India['active_cases']

plt.figure(figsize=(12,6))
plt.plot(x,y)
plt.xlabel('Date')
plt.ylabel('Active Cases')
plt.title('Active Cases According to Date')
# Out:
# Text(0.5, 1.0, 'Active Cases According to Date')

# %% [markdown]
# ### Comparison of Total Deaths in India VS USA

# %%
India=df[df['country']=='India']
USA=df[df['country']=='USA']

x=India['daily_new_deaths'].sum()
y=USA['daily_new_deaths'].sum()

plt.bar(['India','USA'],[x,y],color=['orange','blue'])
plt.xlabel("Countries")
plt.ylabel("Total no. of Cases")
plt.title(' Total Deaths India VS USA')
plt.show()

# %% [markdown]
# ### Top 10 Countries by total COVID-19 Cases

# %%
data=df.groupby('country')['daily_new_cases'].sum()

# %%
top10 = data.sort_values(ascending=False).head(10)

# Plot bar chart
plt.figure(figsize=(10,6))
plt.bar(top10.index, top10.values, color="crimson")
plt.title('Top 10 countries by total COVID-19 Cases')
plt.xlabel('Countries')
plt.ylabel('Total Cases')
plt.show()

# %% [markdown]
# ### Top 10 countries by total deaths

# %%
country_deaths = df.groupby('country')['cumulative_total_deaths'].max().sort_values(ascending=False)

plt.figure(figsize=(10,6))
country_deaths.head(10).plot(kind='bar', color='salmon')
plt.title('Top 10 Countries by Total Deaths', fontsize=14)
plt.ylabel('Total Deaths')
plt.xlabel('Country')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Line plots of total cases for multiple countries.

# %%
df['date'] = pd.to_datetime(df['date'])
countries = ["India", "United States", "Brazil", "Russia", "United Kingdom"]
plt.figure(figsize=(12,6))


for country in countries:
    country_data = df[df['country'] == country]
    plt.plot(country_data['date'], 
             country_data['cumulative_total_cases'], 
             label=country)

plt.title("Cumulative Total COVID-19 Cases - Country Comparison", fontsize=16)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Cumulative Total Cases", fontsize=12)
plt.legend()
plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🧾 Conclusion
#
# - Conducted EDA on COVID-19 global data using **Pandas**, **Matplotlib**, and **Seaborn**.
# - Analyzed **country-wise** and **time-based** trends of cases and deaths.
# - Derived new feature **Case Fatality Rate (CFR)** to study mortality impact.
# - Found that a few countries contribute disproportionately to total cases and deaths.
# - Visualizations effectively showcased pandemic progression and relationships between metrics.
